# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(A, B):
    """
    請完成這個 Function 後往下執行
    """
    return ((A - B)**2).mean(axis=0)

# %%
def mean_absolute_error(A, B):
    return (abs(A - B)).mean(axis=0)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 186.309
# The Mean absolute error is 10.458

# %%
作業1:

所選的competition 為 House Prices: Advanced Regression Techniques （https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview）

1. 你選的這組資料為何重要

Ans: 可幫助屋主如何決定房屋的售價

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

Ans: 資料由 Dean De Cock提供，是收集 Individual residential property in Ames, Iowa from 2006 to 2010. 

3. 蒐集而來的資料型態為何

Ans： The data set contains 2930 observations and a large number of explanatory variables (23 nominal, 23 ordinal, 14 discrete, and 20 continuous) involved in assessing home values. 

4. 這組資料想解決的問題如何評估

Ans: Submissions are evaluated on Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price.


作業2:

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

Ans：透過車輛參數分析，是否可預測車輛業績？並找到業績在前百分之二十的車輛的共通參數為何？

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

Ans：實際訪談司機，詢問車輛的車型及每天載客的主要地區，時段，是否會準備小點心，水，以及是否會與客人互動等

3. 蒐集而來的資料型態為何

Ans：布林/文字/整數

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

Ans：透過 Root-Mean-Squared-Error (RMSE) 去比對預測業績與實際業績之間的差值，如果都小於設定值，則表示業績是可預測的
